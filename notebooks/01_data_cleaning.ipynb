# %% [markdown]
# # 1. Очистка и переработка данных
# **Цель:** Загрузить данные, удалить мусор и подготовить датасет для дальнейшего анализа.
#
# **Источник данных:** Циан, апрель 2025 года, 1399 объявлений о продаже квартир в Москве.

# %% [markdown]
# 1.1 Импортирование библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1.2 Загрузга данных

# %%
df = pd.read_csv('../data/cian_flat_sale_1_57_moskva_19_Apr_2025_13_59_22_202458.csv', sep=';')
print("Количество строк и колонок")
print(df.shape)
# Out:
# Количество строк и колонок
# (1399, 24)

# %% [markdown]
# 1.3 Вывод первых 5 строк

# %%
df.head(5)
# Out:
#             author        author_type  \
# 0           VESPER          developer
# 1  Аврора Проперти  real_estate_agent
# 2   Мария Науменко            realtor
# 3           VESPER          developer
# 4         NF GROUP  real_estate_agent
#
#                                         url location deal_type  \
# 0  https://www.cian.ru/sale/flat/308803465/   Москва      sale
# 1  https://www.cian.ru/sale/flat/308799411/   Москва      sale
# 2  https://www.cian.ru/sale/flat/315881967/   Москва      sale
# 3  https://www.cian.ru/sale/flat/286258299/   Москва      sale
# 4  https://www.cian.ru/sale/flat/306350609/   Москва      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters  ...  \
# 0               flat      1             6            2         173.3  ...
# 1               flat      2             5            3         146.8  ...
# 2               flat      9             9            2          44.0  ...
# 3               flat      5             9            2         104.2  ...
# 4               flat      2             8           -1         235.8  ...
#
#    heating_type                   finish_type  living_meters kitchen_meters  \
# 0            -1  Чистовая, чистовая с мебелью             -1             -1
# 1            -1                            -1             -1          15 м²
# 2            -1                            -1          35 м²           6 м²
# 3            -1            Чистовая с мебелью             -1          28 м²
# 4            -1                            -1             -1          20 м²
#
#          phone      district                    street house_number  \
# 0  74951476131   Пресненский      Патриаршие Пруды мкр          NaN
# 1  79652530061     Хамовники  Пречистенская набережная           43
# 2  79151108860  Левобережный             Фестивальная            11
# 3  74951474575      Тверской      1-я Тверская-Ямская            2А
# 4  79680684965     Хамовники             Льва Толстого         23к1
#
#      underground   residential_complex
# 0     Пушкинская  Клубный дом Левенсон
# 1  Кропоткинская           Carré Blanc
# 2  Речной вокзал                   NaN
# 3     Маяковская      Vesper Tverskaya
# 4  Парк Культуры             Литератор
#
# [5 rows x 24 columns]

# %% [markdown]
# 1.4 Структура данных

# %%
print("Типы данных в каждой колонке")
print(df.dtypes)
# Out:
# Типы данных в каждой колонке
# author                      str
# author_type                 str
# url                         str
# location                    str
# deal_type                   str
# accommodation_type          str
# floor                     int64
# floors_count              int64
# rooms_count               int64
# total_meters            float64
# price                   float64
# year_of_construction        str
# object_type               int64
# house_material_type         str
# heating_type              int64
# finish_type                 str
# living_meters               str
# kitchen_meters              str
# phone                     int64
# district                    str
# street                      str
# house_number                str
# underground                 str
# residential_complex         str
# dtype: object

# %% [markdown]
# 1.5 Вывод пропусков в каждой колонке

# %%
print("Колличество пустых значений")
print(df.isnull().sum())
# Out:
# Колличество пустых значений
# author                    0
# author_type               0
# url                       0
# location                  0
# deal_type                 0
# accommodation_type        0
# floor                     0
# floors_count              0
# rooms_count               0
# total_meters              0
# price                    20
# year_of_construction      0
# object_type               0
# house_material_type       0
# heating_type              0
# finish_type               0
# living_meters             0
# kitchen_meters            0
# phone                     0
# district                 19
# street                   74
# house_number            104
# underground              10
# residential_complex     333
# dtype: int64

# %% [markdown]
# 1.6 Удаление ненужных колонок и строк без цен

# %%
df = df.drop(['url', 'phone', 'object_type', 'heating_type'], axis=1)
df = df.dropna(subset=['price'])
print(f"После удаления пустых цен: {len(df)} строк осталось")
# Out:
# После удаления пустых цен: 1379 строк осталось

# %% [markdown]
# 1.7 Создание колонки "Цена за квадратный метр" и удаление выбросов

# %%
df['price_per_m2'] = df['price'] / df['total_meters']
df = df[(df['price_per_m2']>200000)&(df['price_per_m2']<3000000)]
print(f"После удаления выбросов: {len(df)} строк осталось")
# Out:
# После удаления выбросов: 1350 строк осталось

# %% [markdown]
# 1.8 Чистка районов от мусора

# %%
df['district_len'] = df['district'].str.len()
df = df[df['district_len'] < 20]
df = df.drop(['district_len'], axis=1)
print("Муссор в названиях районов удалён")
# Out:
# Муссор в названиях районов удалён

# %% [markdown]
# 1.9 Медианная цена за квадратный метр

# %%
median_price = df['price_per_m2'].median()
print("Медиана за квадратный метр:")
print(median_price)
# Out:
# Медиана за квадратный метр:
# 768826.6199649738

# %% [markdown]
# 1.10 Сохранение очищенного датасета

# %%
df.to_csv('../data/cian_final_cleaned.csv', index=False)
print("Очищенные данные сохранены в data/cian_cleaned.csv")
# Out:
# Очищенные данные сохранены в data/cian_cleaned.csv
